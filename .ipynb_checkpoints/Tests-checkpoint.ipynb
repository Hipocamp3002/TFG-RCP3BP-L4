# %%
using DifferentialEquations
using Plots
using LinearAlgebra
using DiffEqPhysics
include("RCP3BP.jl")
# Out:
# hamiltonian (generic function with 1 method)

# %% [markdown]
# Probando valores propios

# %%
mu = 0.3
vaps = eigenValues(mu)
veps = eigenVectors(mu)
A = X_H(mu)
for i = 1:4
    println(repr("text/plain",A*veps[i] - vaps[i]*veps[i]))
end
veps
# Out:
# 4-element Vector{ComplexF64}:
#  -4.440892098500626e-16 - 1.1102230246251565e-16im
#  1.6653345369377348e-16 + 5.551115123125783e-17im
#   2.498001805406602e-16 + 1.6653345369377348e-16im
#                     0.0 - 2.220446049250313e-16im
# 4-element Vector{ComplexF64}:
#  -4.440892098500626e-16 + 1.1102230246251565e-16im
#  1.6653345369377348e-16 - 5.551115123125783e-17im
#   2.498001805406602e-16 - 1.6653345369377348e-16im
#                     0.0 + 2.220446049250313e-16im
# 4-element Vector{ComplexF64}:
#  -1.1102230246251565e-16 + 2.220446049250313e-16im
#    2.220446049250313e-16 - 5.551115123125783e-16im
#   2.0816681711721685e-16 - 1.3877787807814457e-16im
#   1.1102230246251565e-16 - 5.551115123125783e-16im
# 4-element Vector{ComplexF64}:
#  -1.1102230246251565e-16 - 2.220446049250313e-16im
#    2.220446049250313e-16 + 5.551115123125783e-16im
#   2.0816681711721685e-16 + 1.3877787807814457e-16im
#   1.1102230246251565e-16 + 5.551115123125783e-16im
# 4-element Vector{Vector{ComplexF64}}:
#  [0.6812322293993748 + 0.0im, -0.014349143831414349 + 0.4498704462014923im, 0.41465296032349447 + 0.1764536078506783im, 0.2591901029489342 + 0.25115905446170095im]
#  [0.6812322293993748 - 0.0im, -0.014349143831414349 - 0.4498704462014923im, 0.41465296032349447 - 0.1764536078506783im, 0.2591901029489342 - 0.25115905446170095im]
#  [0.6232353450228706 + 0.0im, -0.19089701224741454 + 0.49173438164917915im, -0.17532683392230802 + 0.08126740992413957im, 0.2833097530174197 - 0.46446208302674596im]
#  [0.6232353450228706 - 0.0im, -0.19089701224741454 - 0.49173438164917915im, -0.17532683392230802 - 0.08126740992413957im, 0.2833097530174197 + 0.46446208302674596im]

# %% [markdown]
# Trobar coeficients $C_0$ i $C_1$ que eliminin part imaginària.
#
# $C_0 - C_1 = 0$
#
# Suposem $C_0 = cos(\theta), C_1 = sin(\theta)$, aleshores,$\theta = \pi / 4$
